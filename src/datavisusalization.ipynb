# %%
from utils.loadData import loadData, loadDataWithNews
from lstm.preprocessing import dataToTimeSeriesMultiDimensional, getDatasetsMultiDimensional, normalizeAtOnce
from lstm.model import getModel, evaluateModelQuick, evaluateFinal
from lstm.visualization import visualize_loss, show_batch, show_data_simple, showRegressionExampleMultiDimensional
from lstm.callbacks import es_callback, modelckpt_callback
from keras.utils.vis_utils import plot_model

# %%
df = loadData()
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
features = df.loc[:, df.columns != 'Date']
features = features.loc[:, features.columns != 'Adj Close']

normalized_data, scaler = normalizeAtOnce(features)

# %%
features.head()
# Out:
#          Open        High         Low       Close    Volume
# 0  465.864014  468.174011  452.421997  457.334015  21056800
# 1  456.859985  456.859985  413.104004  424.440002  34483200
# 2  424.102997  427.834991  384.532013  394.795990  37919700
# 3  394.673004  423.295990  389.882996  408.903992  36863600
# 4  408.084991  412.425995  393.181000  398.821014  26580100

# %%
normalized_data.shape
# Out:
# (2774, 5)

# %%
show_data_simple(features["Close"], df["Date"])
show_data_simple(normalized_data[:,3], df["Date"])

# %%
show_data_simple(features["Open"], df["Date"], "Open Price")
show_data_simple(normalized_data[:,0], df["Date"], "Open Price")

# %%
show_data_simple(features["High"], df["Date"], "High Price")
show_data_simple(normalized_data[:,1], df["Date"], "High Price")

# %%
show_data_simple(features["Low"], df["Date"], "Low Price")
show_data_simple(normalized_data[:,2], df["Date"], "Low Price")

# %%
show_data_simple(features["Volume"], df["Date"], "Trading Volume")
show_data_simple(normalized_data[:,4], df["Date"], "Trading Volume")
